# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/laptop_data.csv')

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.sample(5)
# Out:
#      Unnamed: 0 Company            TypeName  Inches       ScreenResolution  \
# 776         776  Lenovo            Notebook    15.6  4K Ultra HD 3840x2160
# 842         842      HP            Notebook    17.3               1600x900
# 77           77    Dell            Notebook    15.6      Full HD 1920x1080
# 273         273  Lenovo  2 in 1 Convertible    14.0  Touchscreen 2560x1440
# 440         440  Lenovo            Notebook    17.3               1600x900
#
#                              Cpu   Ram                Memory  \
# 776  Intel Core i7 6820HQ 2.7GHz  16GB             512GB SSD
# 842   Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 77    Intel Core i7 8550U 1.8GHz   8GB  128GB SSD +  1TB HDD
# 273   Intel Core i7 6600U 2.6GHz  16GB             512GB SSD
# 440    AMD A6-Series 9220 2.5GHz   8GB               1TB HDD
#
#                         Gpu       OpSys  Weight      Price
# 776    Nvidia Quadro M2000M   Windows 7   2.5kg  126273.60
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df['Weight'].value_counts()
# Out:
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: Weight, Length: 179, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB',' ')
df['Weight']=df['Weight'].str.replace('kg',' ')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # **EDA**

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-16-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(data=df,x='Company',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(data=df,x='TypeName',y='Price')
plt.xticks(rotation='vertical')
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Ultrabook'),
#   Text(1, 0, 'Notebook'),
#   Text(2, 0, 'Netbook'),
#   Text(3, 0, 'Gaming'),
#   Text(4, 0, '2 in 1 Convertible'),
#   Text(5, 0, 'Workstation')])

# %%
sns.scatterplot(data=df,x='Inches',y='Price')
# There is no as such strong relation between inches and price
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if "Touchscreen" in x else 0)

# %%
df.sample(15)
# Out:
#      Company            TypeName  Inches  \
# 796     Asus            Notebook    14.0
# 627   Lenovo            Notebook    15.6
# 248       HP            Notebook    13.3
# 851     Asus              Gaming    15.6
# 95      Acer  2 in 1 Convertible    13.3
# 390     Asus              Gaming    17.3
# 1016      HP            Notebook    15.6
# 1224    Dell  2 in 1 Convertible    15.0
# 126       HP            Notebook    14.0
# 1088      HP            Notebook    13.3
# 570       HP         Workstation    17.3
# 283   Lenovo            Notebook    15.6
# 263     Dell            Notebook    15.6
# 101       HP            Notebook    15.6
# 345   Lenovo              Gaming    15.6
#
#                                ScreenResolution  \
# 796                                    1366x768
# 627                           Full HD 1920x1080
# 248                 IPS Panel Full HD 1920x1080
# 851                           Full HD 1920x1080
# 95    IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(data=df,x='Touchscreen',y='Price')
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['ips']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 949     Acer            Notebook    14.0
# 115       HP  2 in 1 Convertible    13.3
# 742  Toshiba            Notebook    14.0
# 420   Lenovo  2 in 1 Convertible    15.6
# 430  Samsung             Netbook    11.6
#
#                                   ScreenResolution  \
# 949                                       1366x768
# 115      IPS Panel Full HD / Touchscreen 1920x1080
# 742      IPS Panel Full HD / Touchscreen 1920x1080
# 420  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 430                                       1366x768
#
#                                       Cpu  Ram              Memory  \
# 949  Intel Celeron Dual Core N3060 1.6GHz    4  32GB Flash Storage
# 115            Intel Core i5 8250U 1.6GHz    8           256GB SSD
# 742            Intel Core i5 7200U 2.5GHz    8           256GB SSD
# 420           Intel Core i7 7700HQ 2.8GHz   16           512GB SSD
# ...

# %%
df['ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['ips'],y=df['Price'])
# Out:
# <Axes: xlabel='ips', ylabel='Price'>

# %%
x=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
x.head()
# Out:
#                                0     1
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df['x_reso']=x[0]
df['y_reso']=x[1]

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches   ScreenResolution  \
# 1      Apple  Ultrabook    13.3           1440x900
# 631     Dell     Gaming    15.6  Full HD 1920x1080
# 5       Acer   Notebook    15.6           1366x768
# 1120    Vero   Notebook    13.3  Full HD 1920x1080
# 338     Asus   Notebook    15.6           1366x768
#
#                                        Cpu  Ram                Memory  \
# 1                     Intel Core i5 1.8GHz    8   128GB Flash Storage
# 631            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 5                  AMD A9-Series 9420 3GHz    4             500GB HDD
# 1120           Intel Atom X5-Z8350 1.44GHz    4    32GB Flash Storage
# 338   Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
#
#                              Gpu       OpSys  Weight       Price  Touchscreen  \
# 1         Intel HD Graphics 6000       macOS    1.34  47895.5232            0
# ...

# %%
df['x_reso']=df['x_reso'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_reso']=df['x_reso'].astype('int')
df['y_reso']=df['y_reso'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  ips               1303 non-null   int64
#  13  x_reso            1303 non-null   int64
#  14  y_reso            1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# <ipython-input-39-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# ips            0.252208
# x_reso         0.556529
# y_reso         0.552809
# Name: Price, dtype: float64

# %%
# Pixel per inches
df['ppi']=(((df['x_reso']**2)+(df['y_reso']**2))**0.5)/df['Inches'].astype('float64')

# %%
df.corr()['Price']
# Out:
# <ipython-input-41-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# ips            0.252208
# x_reso         0.556529
# y_reso         0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','x_reso','y_reso','Inches'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['cpu names']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu names
# ...

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text =='Intel Core i5' or text =='Intel Core i3':
    return text
  else:
    if text.split()[0]=='Intel':
      return 'other intel processor'
    else:
      return 'AMD Processor'

# %%
df['cpu brands']=df['cpu names'].apply(fetch_processor)

# %%
df.head(5)
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu names     cpu brands
# ...

# %%
df['cpu brands'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(data=df,x='cpu brands',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','cpu names'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  ips         ppi     cpu brands
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(data=df,x='Ram',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  ips         ppi     cpu brands
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')

# 'Memory' column contains values like "8+4 GB", "16+16 GB", "32 GB", the result of this operation will create a DataFrame with two columns:
# the first column will contain the values "8", "16", "32" (extracting the values before the '+'), and the second column will contain "4 GB", "16 GB",and NaN

new=df['Memory'].str.split('+',n=1,expand=True)

df['first']=new[0]
df['first']=df['first'].str.strip()

df['second']=new[1]
#new[1].value_counts()

df['Layer1HDD']=df['first'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if 'SSD' in x else 0 )
df['Layer1hybrid']=df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer1FlashStorage']=df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)

df['first']=df['first'].str.replace(r'\D',"")

# Replace none values with zero
df['second'].fillna('0', inplace=True)

df['Layer2HDD']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2hybrid']=df['second'].apply(lambda x:1 if 'Hybrid' else 0)
df['Layer2FlashStorage']=df['second'].apply(lambda x:1 if 'Flash storage' in x else 0)

df['second']=df['second'].str.replace(r'\D','')

df['first']=df['first'].astype(int)
df['second']=df['second'].astype(int)

df['HDD']=(df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD'])
df['SSD']=(df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD'])
df['hybrid']=(df['first']*df['Layer1hybrid']+df['second']*df['Layer2hybrid'])
df['flash storage']=(df['first']*df['Layer1FlashStorage']+df['second']*df['Layer2FlashStorage'])


df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1hybrid',
       'Layer1FlashStorage', 'Layer2HDD', 'Layer2SSD', 'Layer2hybrid',
       'Layer2FlashStorage'],inplace=True)
# Out:
# <ipython-input-58-f1ab6097731d>:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first']=df['first'].str.replace(r'\D',"")
# <ipython-input-58-f1ab6097731d>:31: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second']=df['second'].str.replace(r'\D','')

# %%
df.sample(5)
# Out:
#       Company     TypeName  Ram                Memory  \
# 636      Dell    Ultrabook    8               256 SSD
# 950        HP  Workstation    8                 8 SSD
# 723      Dell       Gaming   32  1000 SSD +  1000 HDD
# 768   Samsung    Ultrabook    8               256 SSD
# 1096     Dell     Notebook    8              1000 HDD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen  \
# 636    Intel UHD Graphics 620  Windows 10    1.23   99580.320            1
# 950      Nvidia Quadro M1000M  Windows 10    2.00  119826.720            0
# 723   Nvidia GeForce GTX 1070  Windows 10    4.36  194972.832            0
# 768     Intel HD Graphics 620  Windows 10    1.31   85194.720            1
# 1096       AMD Radeon R7 M445  Windows 10    2.36   34035.264            0
#
#       ips         ppi     cpu brands   HDD   SSD  hybrid  flash storage
# 636     0  276.053530  Intel Core i5     0   256       0              0
# ...

# %%
df.drop(columns=['Memory'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  ips         ppi     cpu brands  HDD  SSD  hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    flash storage
# 0              0
# 1            128
# ...

# %%
df.corr()['Price']
# Out:
# <ipython-input-62-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# hybrid           0.282645
# flash storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['flash storage','hybrid'],inplace=True)

# %%
df['Gpu brands']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  ips         ppi     cpu brands  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brands
# 0      Intel
# 1      Intel
# 2      Intel
# 3        AMD
# 4      Intel

# %%
df['Gpu brands'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brands, dtype: int64

# %%
df=df[df['Gpu brands'] != 'ARM']

# %%
df['Gpu brands'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brands, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  ips         ppi     cpu brands  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brands
# 0      Intel
# 1      Intel
# 2      Intel
# 3        AMD
# 4      Intel

# %%
sns.barplot(data=df,x='Gpu brands',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi     cpu brands  HDD  SSD Gpu brands
# 0  226.983005  Intel Core i5    0  128      Intel
# 1  127.677940  Intel Core i5    0    0      Intel
# 2  141.211998  Intel Core i5    0  256      Intel
# 3  220.534624  Intel Core i7    0  512        AMD
# 4  226.983005  Intel Core i5    0  256      Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(data=df,x='OpSys',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
def laptop_os(inp):
  if inp == 'Windows 10'or inp == 'Windows 7' or inp == 'Windows 10 S':
    return 'windows'
  elif inp == 'macOS' or inp == 'Mac OS X':
    return 'mac'
  else:
    return 'others/no os/Linux'

# %%
df['os']=df['OpSys'].apply(laptop_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi     cpu brands  HDD  SSD Gpu brands                  os
# 0  226.983005  Intel Core i5    0  128      Intel                 mac
# 1  127.677940  Intel Core i5    0    0      Intel                 mac
# 2  141.211998  Intel Core i5    0  256      Intel  others/no os/Linux
# 3  220.534624  Intel Core i7    0  512        AMD                 mac
# 4  226.983005  Intel Core i5    0  256      Intel                 mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(data=df,x='os',y='Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#       cpu brands  HDD  SSD Gpu brands                  os
# 0  Intel Core i5    0  128      Intel                 mac
# 1  Intel Core i5    0    0      Intel                 mac
# 2  Intel Core i5    0  256      Intel  others/no os/Linux
# 3  Intel Core i7    0  512        AMD                 mac
# 4  Intel Core i5    0  256      Intel                 mac

# %%
sns.distplot(df['Weight'])
# Out:
# <ipython-input-81-05ee4c8848be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df.corr()['Price']
# Out:
# <ipython-input-82-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-83-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
import numpy as np

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-85-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRFRegressor

# %% [markdown]
# #**Linear Regresion**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


step2=LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print('r2_score',r2_score(y_test,y_pred))
print('mae score',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8073277448418629
# mae score 0.2101782797642888
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # **Ridge Regression**

# %%
step1=ColumnTransformer(
    transformers=[
        ('col_tnf',OneHotEncoder(sparse=True,drop='first'),[0,1,7,10,11])
    ],remainder='passthrough'
)

step2=Ridge(alpha=6)

pipe=Pipeline(
    [
        ('step1',step1),
        ('step2',step2)
    ]
)

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print('r2 score',r2_score(y_test,y_pred))
print('mae', mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 score 0.81208966729468
# mae 0.2092579615888917

# %% [markdown]
# # **Lasso Regression**

# %%
X_train.head(1)
# Out:
#      Company  TypeName  Ram  Weight  Touchscreen  ips        ppi  \
# 183  Toshiba  Notebook    8     2.0            0    0  100.45467
#
#         cpu brands  HDD  SSD Gpu brands       os
# 183  Intel Core i5    0  128      Intel  windows

# %%
step1=ColumnTransformer(
    transformers=[
        (
            'coltnf',OneHotEncoder(sparse=True,drop='first'),[0,1,7,10,11]
        )
    ],remainder='passthrough'
)

step2=Lasso(alpha=0.0001)

pipe=Pipeline(
    [
        ('step1',step1),
        ('step2',step2)
    ]
)

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print('r2_score',r2_score(y_test,y_pred))
print('mae_score',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2_score 0.8082917416674594
# mae_score 0.20991753228302445

# %% [markdown]
# # **KNN**

# %%
step1=ColumnTransformer(
    transformers=[
        (
            'coltnf',OneHotEncoder(sparse=True,drop='first'),[0,1,7,10,11]
        )
    ],remainder='passthrough'
)

step2=KNeighborsRegressor()


pipe=Pipeline(
    [
      ('step1',step1),
      ('step2',step2)
    ]
)

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print('r2_score',r2_score(y_test,y_pred))
print('mae_score',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2_score 0.8006892209563684
# mae_score 0.20050928983818136

# %% [markdown]
# # **Decision Tree**

# %%
step1=ColumnTransformer(
    transformers=[
        ('coltnf',OneHotEncoder(sparse=True,drop='first'),[0,1,7,10,11])
    ],remainder='passthrough'
)

step2=DecisionTreeRegressor()

pipe=Pipeline(
    [
        ('step1',step1),
        ('step2',step2)
    ]
)

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8034604337205865
# MAE 0.19905666865057237
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # **SVM**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=SVR(kernel='rbf', C=10000, epsilon=0.1 )

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8083180902272435
# MAE 0.20239059427315706

# %% [markdown]
# # Random Forest Regressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=RandomForestRegressor(
    n_estimators=100,
    random_state=3,
    max_samples=0.5,
    max_features=0.75,
    max_depth=15

)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# # ExtraTrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15,
                              bootstrap=True
                            )

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8850720167552375
# MAE 0.16154538000217084

# %% [markdown]
# # AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7897343889383979
# MAE 0.23266322442402615
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8830079528803629
# MAE 0.1590792992303559
